# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('seaborn')
sns.set_theme()
# Out:
# Matplotlib is building the font cache; this may take a moment.
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\matplotlib\style\core.py:129, in use(style)
#     128 try:
# --> 129     style = _rc_params_in_file(style)
#     130 except OSError as err:
#
# File ~\anaconda3\Lib\site-packages\matplotlib\__init__.py:903, in _rc_params_in_file(fname, transform, fail_on_error)
#     902 rc_temp = {}
# --> 903 with _open_file_or_url(fname) as fd:
#     904     try:
#
# File ~\anaconda3\Lib\contextlib.py:141, in _GeneratorContextManager.__enter__(self)
#     140 try:
# --> 141     return next(self.gen)
#     142 except StopIteration:
#
# File ~\anaconda3\Lib\site-packages\matplotlib\__init__.py:880, in _open_file_or_url(fname)
#     879 fname = os.path.expanduser(fname)
# --> 880 with open(fname, encoding='utf-8') as f:
#     881     yield f
#
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('seaborn-v0_8')
sns.set_theme()

# %%
product_sales = df.groupby('Product')['TotalAmount'].sum().sort_values(ascending=False)
product_sales.plot(kind='bar', color='skyblue', figsize=(10, 6))
plt.title('Total Sales by Product')
plt.xlabel('Product')
plt.ylabel('Total Revenue')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 product_sales = df.groupby('Product')['TotalAmount'].sum().sort_values(ascending=False)
#       2 product_sales.plot(kind='bar', color='skyblue', figsize=(10, 6))
#       3 plt.title('Total Sales by Product')
#
# NameError: name 'df' is not defined

# %%
import pandas as pd
df = pd.read_excel("Retail Store Transactions.csv.xlsx")
df.head()
# Out:
#         Date   Time StoreID Location  Product  Quantity  UnitPrice  \
# 0 2024-03-30  15:29      S3  Store C   Tablet         3     364.22
# 1 2023-03-16  16:53      S1  Store B  Printer         9     384.74
# 2 2024-04-26  21:22      S9  Store B   Laptop         9     397.80
# 3 2025-02-08  14:28      S9  Store C  Monitor         7      80.27
# 4 2024-06-17  20:00      S9  Store A  Monitor        10     214.03
#
#   PaymentType TransactionID Cashier StoreManager  TimeOfDay DayOfWeek  \
# 0   Gift Card      TX300000      C1         Noah  Afternoon  Saturday
# 1      Online      TX300001      C5         Liam  Afternoon  Thursday
# 2  Debit Card      TX300002      C3         Liam    Evening    Friday
# 3      Online      TX300003      C2          Mia  Afternoon  Saturday
# 4   Gift Card      TX300004      C1         Noah    Evening    Monday
#
#    TotalPrice
# 0     1092.66
# 1     3462.66
# 2     3580.20
# 3      561.89
# 4     2140.30

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49 entries, 0 to 48
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           49 non-null     datetime64[ns]
#  1   Time           49 non-null     object
#  2   StoreID        49 non-null     object
#  3   Location       49 non-null     object
#  4   Product        49 non-null     object
#  5   Quantity       49 non-null     int64
#  6   UnitPrice      49 non-null     float64
#  7   PaymentType    49 non-null     object
#  8   TransactionID  49 non-null     object
#  9   Cashier        49 non-null     object
#  10  StoreManager   49 non-null     object
#  11  TimeOfDay      49 non-null     object
#  12  DayOfWeek      49 non-null     object
#  13  TotalPrice     49 non-null     float64
# dtypes: datetime64[ns](1), float64(2), int64(1), object(10)
# memory usage: 5.5+ KB

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('seaborn-v0_8')
sns.set_theme()

product_sales = df.groupby('Product')['TotalAmount'].sum().sort_values(ascending=False)

plt.figure(figsize=(10, 6))
sns.barplot(x=product_sales.index, y=product_sales.values, palette='pastel')

plt.title('Total Sales by Product')
plt.xlabel('Product')
plt.ylabel('Total Revenue')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 7
#       4 plt.style.use('seaborn-v0_8')
#       5 sns.set_theme()
# ----> 7 product_sales = df.groupby('Product')['TotalAmount'].sum().sort_values(ascending=False)
#       9 plt.figure(figsize=(10, 6))
#      10 sns.barplot(x=product_sales.index, y=product_sales.values, palette='pastel')
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\generic.py:1951, in DataFrameGroupBy.__getitem__(self, key)
#    1944 if isinstance(key, tuple) and len(key) > 1:
#    1945     # if len == 1, then it becomes a SeriesGroupBy and this is actually
#    1946     # valid syntax, so don't raise
#    1947     raise ValueError(
#    1948         "Cannot subset columns with a tuple with more than one element. "
#    1949         "Use a list instead."
#    1950     )
# -> 1951 return super().__getitem__(key)
#
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('seaborn-v0_8')
sns.set_theme()

product_sales = df.groupby('Product')['TotalPrice'].sum().sort_values(ascending=False)

plt.figure(figsize=(10, 6))
sns.barplot(x=product_sales.index, y=product_sales.values, palette='pastel')

plt.title('Total Sales by Product')
plt.xlabel('Product')
plt.ylabel('Total Revenue')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_3212\3811706916.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=product_sales.index, y=product_sales.values, palette='pastel')

# %%
df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate']) 
sales_over_time = df.groupby(df['InvoiceDate'].dt.to_period('M'))['TotalPrice'].sum()

sales_over_time.plot(kind='line', marker='o', figsize=(10, 5), title='Monthly Sales Trend')
plt.ylabel('Total Sales')
plt.xlabel('Month')
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'InvoiceDate'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'])
# ...

# %%
product_sales = df.groupby('Product')['TotalPrice'].sum().sort_values(ascending=False)

plt.figure(figsize=(10, 5))
sns.barplot(x=product_sales.index, y=product_sales.values, palette='magma')
plt.title('Total Sales by Product')
plt.xlabel('Product')
plt.ylabel('Revenue')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_3212\690496929.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=product_sales.index, y=product_sales.values, palette='magma')

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(x='TimeOfDay', y='TotalPrice', data=df, palette='Set2')
plt.title('Sales Distribution by Time of Day')
plt.xlabel('Time of Day')
plt.ylabel('Revenue')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_3212\3060033343.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='TimeOfDay', y='TotalPrice', data=df, palette='Set2')

# %%
day_order = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
day_sales = df.groupby('DayOfWeek')['TotalPrice'].sum().reindex(day_order)

plt.figure(figsize=(9, 5))
sns.lineplot(x=day_sales.index, y=day_sales.values, marker='o', color='blue')
plt.title('Total Sales by Day of the Week')
plt.xlabel('Day')
plt.ylabel('Revenue')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
top_customers = df.groupby('Cashier')['TotalPrice'].sum().nlargest(5)

plt.figure(figsize=(8, 5))
sns.barplot(x=top_customers.index, y=top_customers.values, palette='coolwarm')
plt.title('Top 5 Cashiers by Sales')
plt.xlabel('Cashier')
plt.ylabel('Total Revenue')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_3212\2074509399.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_customers.index, y=top_customers.values, palette='coolwarm')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='UnitPrice', y='TotalPrice', hue='Product', style='Product', s=100)
plt.title('Price Sensitivity by Product')
plt.xlabel('Unit Price')
plt.ylabel('Total Revenue')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
store_sales = df.groupby('Location')['TotalPrice'].sum().sort_values(ascending=False)
store_sales_pct = store_sales / store_sales.sum() * 100

plt.figure(figsize=(8, 6))
store_sales_pct.plot(kind='bar', color='teal')
plt.ylabel('Sales Contribution (%)')
plt.title('Sales Contribution by Store')
plt.tight_layout()
plt.show()

# %%
df['BasketSize'] = df['TotalPrice'] / df['Quantity']

avg_basket = df.groupby('Product')['BasketSize'].mean().sort_values(ascending=False)

plt.figure(figsize=(10, 5))
sns.barplot(x=avg_basket.index, y=avg_basket.values, palette='crest')
plt.title('Average Revenue per Item (Basket Size)')
plt.ylabel('Avg Revenue per Item')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_3212\2445261572.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=avg_basket.index, y=avg_basket.values, palette='crest')
